# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
gen0=np.load("./data/ICML/VDM_Go7_Mcdm_c_c_128/CV/gen_0.npy")

# %%
plt.imshow(np.log10((10**gen0[1,0])[:32].sum(0)))

# %%
plt.imshow(np.log10((10**gen0[:,0]).mean(0)[:32].sum(0)))
